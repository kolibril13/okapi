# %%
from pathlib import Path
import typst
from IPython.display import SVG, display

temp_dir = Path.cwd()
typst_file = temp_dir / "hello.typ"
svg_file = temp_dir / "hello.svg"

file_content = """
#set page(width: auto, height: auto, margin: 0cm, fill: none)
#set text(size: 50pt)
$ sum_(k=1)^n k = (n(n+1)) / 2 $
"""
typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
file_content = """
#set page(width: 800pt, height: auto, margin: 1cm, fill: none)

#import "@preview/codelst:2.0.1": sourcecode
#import "@preview/tablex:0.0.8": tablex

#let sourcecode = sourcecode.with(frame: (code) => block(
  radius: 5pt,
  stroke: luma(30),
  inset: 30pt,
  text(size: 30pt, code)
))

#sourcecode[```python
for i in range(0,10):
  print(i)
```]

"""

typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
file_content = """
#set page(width: 100pt, height: 100pt, margin: 0cm, fill: none)
#box(fill: white, stroke: black)[= Typst] <hello>
#box(fill: white, stroke: black)[= Typst] <world>

$ sum_(k=1)^n k = (n(n+1)) / 2 $  <joho>
"""
typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
# simple equation
file_content = """
#set page(width: auto, height: auto, margin: 0cm, fill: none)
#set text(size: 80pt)
$ a+b=c $
"""

typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
# set title in svg
file_content = """
#set page(width: auto, height: auto, margin: 1cm, fill: none)
#set text(size: 20pt)
#box()[#[== Introduction]] <title>

#box()[#[$ integral_0^(1) x d x = lr(x^2/2|)_0^1 $]] <math>
"""

typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
file_content = """
#set page(width: auto, height: auto, margin: 0cm, fill: none)
#set text(size: 80pt)

#let korange() = text(fill: orange)[$k$]
#let nblue() = text(fill: blue)[$n$]

$ sum_(#korange() = 1)^#nblue() #korange() = (nblue()(nblue()+1)) / 2 $  
"""

typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
file_content = """
#set page(width: auto, height: auto, margin: 0.2cm, fill: none)
#set text(size: 80pt)
#let borange() = text(fill: orange)[$b$]
#let cblue() = text(fill: blue)[$c$]

$a  #borange()  #cblue()$
"""

typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))

# %%
file_content = """
#set page(width: auto, height: auto, margin: 0.2cm, fill: none)
#set text(size: 80pt)
#let borange() = text(fill: orange)[$b$]
#let cblue() = text(fill: blue)[$o$]

$#cblue()$
"""

typst_file.write_text(file_content)
typst.compile(typst_file, format="svg", output=str(svg_file))
display(SVG(filename=str(svg_file)))
